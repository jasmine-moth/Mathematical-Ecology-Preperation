# %% [markdown]
# # The Logistic Equation

# %%
import matplotlib.pyplot as plt 
import numpy as np 


K = 10 #carrying capacity
N_0 = 5 #initial population
r = 2 #intrinsic rate of growth

def N(t): #solution of the logistic equation
    output = K/(1+(k/N_0 - 1)*np.exp(-r*t))
    return output
